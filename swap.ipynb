# %% [markdown]
# <a href="https://colab.research.google.com/github/Maanvijangir/prgm/blob/main/swap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Maanvi Jangir**
# **roll no.250490**

# %% [markdown]
# # **Swap with temp variable...**

# %%
# %%writefile swap.c
# #include<stdio.h>
# void main()
# {
#   int a=2,b=3,temp;
#   temp=a;
#   a=b;
#   b=temp;
#   printf("a=%d  b=%d",a,b);
# }
# Out:
# Overwriting swap.c

# %%
# !gcc swap.c -lm

# %%
# !./a.out
# Out:
# a=3  b=2

# %% [markdown]
# # **Swap without temp var...**

# %%
# %%writefile swap.c
# #include<stdio.h>
# void main()
# {
#   int a=1,b=2;
#   a=a+b;
#   b=a-b;
#   a=a-b;
#   printf("a=%d  b=%d",a,b);
# }
# Out:
# Overwriting swap.c

# %%
# !gcc swap.c -lm

# %%
# !./a.out
# Out:
# a=2  b=1

# %% [markdown]
# # **One line swap**

# %%
# %%writefile swap.c
# #include<stdio.h>
# void main()
# {
#   int a=3, b=6;
#   a=(a*b)/(b=a);
#   printf("a=%d  b=%d",a,b);
# }
# Out:
# Overwriting swap.c

# %%
# !gcc swap.c -lm

# %%
# !./a.out
# Out:
# a=6  b=3

# %% [markdown]
# # **Fibonacci Recursion**

# %%
# %%writefile add.c
# #include <stdio.h>
#
# int fib(int n) {
#     if (n <= 1) {
#         return n;
#     } else {
#         return fib(n - 1) + fib(n - 2);
#     }
# }
#
# int main() {
#     int n;
#     printf("Enter terms: ");
#     scanf("%d", &n);
#
#     for (int i = 0; i < n; i++) {
#         printf("%d ", fib(i));
#     }
#     printf("\n");
#     return 0;
# }
# Out:
# Writing add.c

# %%
# !gcc add.c -lm

# %%
# !./a.out
# Out:
# Enter terms: 9
# 0 1 1 2 3 5 8 13 21

# %% [markdown]
# # **Transpose of a Matrix**

# %%
# %%writefile tran.c
# #include <stdio.h>
#
# int main() {
#
#     int a[10][10];
#     int n, m;
#
#
#     printf("Enter rows and columns: ");
#
#     scanf("%d%d", &n, &m);
#
#
#     printf("Enter elements of the matrix:\n");
#
#     for (int i = 0; i < n; i++) {
#
#         for (int j = 0; j < m; j++) {
#             scanf("%d", &a[i][j]);
#         }
#     }
#
#
#     printf("Transpose of the matrix:\n");
#
#     for (int i = 0; i < m; i++) {
#
#         for (int j = 0; j < n; j++) {
#             printf("%d ", a[j][i]);
#         }
#         printf("\n");
#     }
#     return 0;
# }
# Out:
# Overwriting tran.c

# %%
# !gcc tran.c -lm

# %%
# !./a.out
# Out:
# Enter rows and columns: 3
# 2
# Enter elements of the matrix:
# 1 3 4 6 7 8
# Transpose of the matrix:
# 1 4 7
# 3 6 8

# %% [markdown]
# # **Operations of Matrix**

# %%
# %%writefile matrix.c
# #include <stdio.h>
#
# int main() {
#
#     int a[10][10], b[10][10], c[10][10];
#     int r, c1;
#     int ch;
#
#
#     printf("Enter rows and columns for matrices: ");
#
#     scanf("%d%d", &r, &c1);
#
#
#     printf("Enter elements of the first matrix:\n");
#
#     for (int i = 0; i < r; i++) {
#
#         for (int j = 0; j < c1; j++) {
#             scanf("%d", &a[i][j]); // Read element for matrix 'a'
#         }
#     }
#
#
#     printf("Enter elements of the second matrix:\n");
#
#     for (int i = 0; i < r; i++) {
#
#         for (int j = 0; j < c1; j++) {
#             scanf("%d", &b[i][j]); // Read element for matrix 'b'
#         }
#     }
#
#
#     printf("Choose an operation:\n");
#     printf("1. Addition\n");
#     printf("2. Subtraction\n");
#     printf("3. Multiplication\n");
#     printf("Enter your choice (1, 2, or 3): ");
#     scanf("%d", &ch);
#
#
#     if (ch == 1) { // Matrix Addition
#         printf("Result of Addition:\n");
#         for (int i = 0; i < r; i++) {
#             for (int j = 0; j < c1; j++) {
#                 c[i][j] = a[i][j] + b[i][j];
#                 printf("%d ", c[i][j]);
#             }
#             printf("\n");
#         }
#     } else if (ch == 2) { // Matrix Subtraction
#         printf("Result of Subtraction:\n");
#         for (int i = 0; i < r; i++) {
#             for (int j = 0; j < c1; j++) {
#                 c[i][j] = a[i][j] - b[i][j];
#                 printf("%d ", c[i][j]);
#             }
#             printf("\n");
#         }
#     } else if (ch == 3) { // Matrix Multiplication
#         printf("Result of Multiplication:\n");
#         for (int i = 0; i < r; i++) {
#             for (int j = 0; j < c1; j++) {
#                 c[i][j] = 0;
#                 for (int k = 0; k < c1; k++) {
#                     c[i][j] += a[i][k] * b[k][j];
#                 }
#                 printf("%d ", c[i][j]);
#             }
#             printf("\n");
#         }
#     } else {
#         printf("Invalid choice. Please enter 1, 2, or 3.\n"); // Error for invalid choice
#     }
#
#     return 0; // Indicate successful program execution
# }
# Out:
# Overwriting matrix.c

# %%
# !gcc matrix.c -lm

# %%
# !./a.out
# Out:
# Enter rows and columns for matrices: 2
# 2
# Enter elements of the first matrix:
# 1 2 3  4
# Enter elements of the second matrix:
# 5 6 7 8
# Choose an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# Enter your choice (1, 2, or 3): 3
# Result of Multiplication:
# 19 22
# 43 50

# %% [markdown]
# # **Stack**

# %%
# %%writefile stack.c
# #include <stdio.h>
# #include <string.h>
# #include <stdlib.h>
#
# #define MAX_SIZE 7
#
# typedef struct {
#     char* data[MAX_SIZE];
#     int top;
# } Stack;
#
# void initialize(Stack* s) {
#     s->top = -1;
# }
#
# int is_empty(Stack* s) {
#     return s->top == -1;
# }
#
# int is_full(Stack* s) {
#     return s->top == MAX_SIZE - 1;
# }
#
# void push(Stack* s, char* day) {
#     if (is_full(s)) return;
#     s->top++;
#     s->data[s->top] = day;
# }
#
# char* pop(Stack* s) {
#     if (is_empty(s)) return NULL;
#     return s->data[s->top--];
# }
#
# void print_stack(Stack* s) {
#     for (int i = 0; i <= s->top; i++) {
#         printf("| %-2s ", s->data[i]);
#     }
#     for (int i = s->top + 1; i < MAX_SIZE; i++) {
#         printf("|    ");
#     }
#     printf("|\n");
# }
#
# void shift_days(Stack* input_stack, Stack* output_stack) {
#     while (!is_empty(input_stack)) {
#         push(output_stack, pop(input_stack));
#     }
#
#     char* shifted_day = pop(output_stack);
#
#     while (!is_empty(output_stack)) {
#         push(input_stack, pop(output_stack));
#     }
#
#     push(input_stack, shifted_day);
# }
#
# int main() {
#     char days[MAX_SIZE][3] = {"sa", "su", "mo", "tu", "we", "th", "fr"};
#     Stack input_stack, output_stack;
#
#     initialize(&input_stack);
#     initialize(&output_stack);
#
#     for (int i = 0; i < MAX_SIZE; i++) {
#         push(&input_stack, days[i]);
#     }
#
#     printf("--Day Shifting Simulation using two stacks--\n");
#     printf("|R# | Sa | Su | Mo | Tu | We | Th | Fr |\n");
#     printf("----------------------------------------\n");
#
#     printf("|%-2d ", 1);
#     print_stack(&input_stack);
#
#     for (int i = 2; i <= MAX_SIZE + 1; i++) {
#         shift_days(&input_stack, &output_stack);
#         printf("|%-2d ", i);
#         print_stack(&input_stack);
#     }
#
#     printf("----------------------------------------\n");
#     return 0;
# }
# Out:
# Writing stack.c

# %%
# !gcc stack.c -lm

# %%
# !./a.out
# Out:
# --Day Shifting Simulation using two stacks--
# |R# | Sa | Su | Mo | Tu | We | Th | Fr |
# ----------------------------------------
# |1  | sa | su | mo | tu | we | th | fr |
# |2  | su | mo | tu | we | th | fr | sa |
# |3  | mo | tu | we | th | fr | sa | su |
# |4  | tu | we | th | fr | sa | su | mo |
# |5  | we | th | fr | sa | su | mo | tu |
# |6  | th | fr | sa | su | mo | tu | we |
# |7  | fr | sa | su | mo | tu | we | th |
# |8  | sa | su | mo | tu | we | th | fr |
# ----------------------------------------
