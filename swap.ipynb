# %% [markdown]
# <a href="https://colab.research.google.com/github/Maanvijangir/prgm/blob/main/swap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Maanvi Jangir**
# **roll no.250490**

# %% [markdown]
# # **Swap with temp variable...**

# %%
# %%writefile swap.c
# #include<stdio.h>
# void main()
# {
#   int a=2,b=3,temp;
#   temp=a;
#   a=b;
#   b=temp;
#   printf("a=%d  b=%d",a,b);
# }
# Out:
# Overwriting swap.c

# %%
# !gcc swap.c -lm

# %%
# !./a.out
# Out:
# a=3  b=2

# %% [markdown]
# # **Swap without temp var...**

# %%
# %%writefile swap.c
# #include<stdio.h>
# void main()
# {
#   int a=1,b=2;
#   a=a+b;
#   b=a-b;
#   a=a-b;
#   printf("a=%d  b=%d",a,b);
# }
# Out:
# Overwriting swap.c

# %%
# !gcc swap.c -lm

# %%
# !./a.out
# Out:
# a=2  b=1

# %% [markdown]
# # **One line swap**

# %%
# %%writefile swap.c
# #include<stdio.h>
# void main()
# {
#   int a=3, b=6;
#   a=(a*b)/(b=a);
#   printf("a=%d  b=%d",a,b);
# }
# Out:
# Overwriting swap.c

# %%
# !gcc swap.c -lm

# %%
# !./a.out
# Out:
# a=6  b=3

# %% [markdown]
# # **Fibonacci Recursion**

# %%
# %%writefile add.c
# #include <stdio.h>
#
# int fib(int n) {
#     if (n <= 1) {
#         return n;
#     } else {
#         return fib(n - 1) + fib(n - 2);
#     }
# }
#
# int main() {
#     int n;
#     printf("Enter terms: ");
#     scanf("%d", &n);
#
#     for (int i = 0; i < n; i++) {
#         printf("%d ", fib(i));
#     }
#     printf("\n");
#     return 0;
# }
# Out:
# Writing add.c

# %%
# !gcc add.c -lm

# %%
# !./a.out
# Out:
# Enter terms: 9
# 0 1 1 2 3 5 8 13 21

# %% [markdown]
# # **Transpose of a Matrix**

# %%
# %%writefile tran.c
# #include <stdio.h>
#
# int main() {
#
#     int a[10][10];
#     int n, m;
#
#
#     printf("Enter rows and columns: ");
#
#     scanf("%d%d", &n, &m);
#
#
#     printf("Enter elements of the matrix:\n");
#
#     for (int i = 0; i < n; i++) {
#
#         for (int j = 0; j < m; j++) {
#             scanf("%d", &a[i][j]);
#         }
#     }
#
#
#     printf("Transpose of the matrix:\n");
#
#     for (int i = 0; i < m; i++) {
#
#         for (int j = 0; j < n; j++) {
#             printf("%d ", a[j][i]);
#         }
#         printf("\n");
#     }
#     return 0;
# }
# Out:
# Overwriting tran.c

# %%
# !gcc tran.c -lm

# %%
# !./a.out
# Out:
# Enter rows and columns: 3
# 2
# Enter elements of the matrix:
# 1 3 4 6 7 8
# Transpose of the matrix:
# 1 4 7
# 3 6 8

# %% [markdown]
# # **Operations of Matrix**

# %%
# %%writefile matrix.c
# #include <stdio.h>
#
# int main() {
#
#     int a[10][10], b[10][10], c[10][10];
#     int r, c1;
#     int ch;
#
#
#     printf("Enter rows and columns for matrices: ");
#
#     scanf("%d%d", &r, &c1);
#
#
#     printf("Enter elements of the first matrix:\n");
#
#     for (int i = 0; i < r; i++) {
#
#         for (int j = 0; j < c1; j++) {
#             scanf("%d", &a[i][j]); // Read element for matrix 'a'
#         }
#     }
#
#
#     printf("Enter elements of the second matrix:\n");
#
#     for (int i = 0; i < r; i++) {
#
#         for (int j = 0; j < c1; j++) {
#             scanf("%d", &b[i][j]); // Read element for matrix 'b'
#         }
#     }
#
#
#     printf("Choose an operation:\n");
#     printf("1. Addition\n");
#     printf("2. Subtraction\n");
#     printf("3. Multiplication\n");
#     printf("Enter your choice (1, 2, or 3): ");
#     scanf("%d", &ch);
#
#
#     if (ch == 1) { // Matrix Addition
#         printf("Result of Addition:\n");
#         for (int i = 0; i < r; i++) {
#             for (int j = 0; j < c1; j++) {
#                 c[i][j] = a[i][j] + b[i][j];
#                 printf("%d ", c[i][j]);
#             }
#             printf("\n");
#         }
#     } else if (ch == 2) { // Matrix Subtraction
#         printf("Result of Subtraction:\n");
#         for (int i = 0; i < r; i++) {
#             for (int j = 0; j < c1; j++) {
#                 c[i][j] = a[i][j] - b[i][j];
#                 printf("%d ", c[i][j]);
#             }
#             printf("\n");
#         }
#     } else if (ch == 3) { // Matrix Multiplication
#         printf("Result of Multiplication:\n");
#         for (int i = 0; i < r; i++) {
#             for (int j = 0; j < c1; j++) {
#                 c[i][j] = 0;
#                 for (int k = 0; k < c1; k++) {
#                     c[i][j] += a[i][k] * b[k][j];
#                 }
#                 printf("%d ", c[i][j]);
#             }
#             printf("\n");
#         }
#     } else {
#         printf("Invalid choice. Please enter 1, 2, or 3.\n"); // Error for invalid choice
#     }
#
#     return 0; // Indicate successful program execution
# }
# Out:
# Overwriting matrix.c

# %%
# !gcc matrix.c -lm

# %%
# !./a.out
# Out:
# Enter rows and columns for matrices: 2
# 2
# Enter elements of the first matrix:
# 1 2 3  4
# Enter elements of the second matrix:
# 5 6 7 8
# Choose an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# Enter your choice (1, 2, or 3): 3
# Result of Multiplication:
# 19 22
# 43 50

# %% [markdown]
# # **Stack**

# %%
# %%writefile stack.c
# #include <stdio.h>
# #include <string.h>
# #include <stdlib.h>
#
# #define MAX_SIZE 7
#
# typedef struct {
#     char* data[MAX_SIZE];
#     int top;
# } Stack;
#
# void initialize(Stack* s) {
#     s->top = -1;
# }
#
# int is_empty(Stack* s) {
#     return s->top == -1;
# }
#
# int is_full(Stack* s) {
#     return s->top == MAX_SIZE - 1;
# }
#
# void push(Stack* s, char* day) {
#     if (is_full(s)) return;
#     s->top++;
#     s->data[s->top] = day;
# }
#
# char* pop(Stack* s) {
#     if (is_empty(s)) return NULL;
#     return s->data[s->top--];
# }
#
# void print_stack(Stack* s) {
#     for (int i = 0; i <= s->top; i++) {
#         printf("| %-2s ", s->data[i]);
#     }
#     for (int i = s->top + 1; i < MAX_SIZE; i++) {
#         printf("|    ");
#     }
#     printf("|\n");
# }
#
# void shift_days(Stack* input_stack, Stack* output_stack) {
#     while (!is_empty(input_stack)) {
#         push(output_stack, pop(input_stack));
#     }
#
#     char* shifted_day = pop(output_stack);
#
#     while (!is_empty(output_stack)) {
#         push(input_stack, pop(output_stack));
#     }
#
#     push(input_stack, shifted_day);
# }
#
# int main() {
#     char days[MAX_SIZE][3] = {"sa", "su", "mo", "tu", "we", "th", "fr"};
#     Stack input_stack, output_stack;
#
#     initialize(&input_stack);
#     initialize(&output_stack);
#
#     for (int i = 0; i < MAX_SIZE; i++) {
#         push(&input_stack, days[i]);
#     }
#
#     printf("--Day Shifting Simulation using two stacks--\n");
#     printf("|R# | Sa | Su | Mo | Tu | We | Th | Fr |\n");
#     printf("----------------------------------------\n");
#
#     printf("|%-2d ", 1);
#     print_stack(&input_stack);
#
#     for (int i = 2; i <= MAX_SIZE + 1; i++) {
#         shift_days(&input_stack, &output_stack);
#         printf("|%-2d ", i);
#         print_stack(&input_stack);
#     }
#
#     printf("----------------------------------------\n");
#     return 0;
# }
# Out:
# Writing stack.c

# %%
# !gcc stack.c -lm

# %%
# !./a.out
# Out:
# --Day Shifting Simulation using two stacks--
# |R# | Sa | Su | Mo | Tu | We | Th | Fr |
# ----------------------------------------
# |1  | sa | su | mo | tu | we | th | fr |
# |2  | su | mo | tu | we | th | fr | sa |
# |3  | mo | tu | we | th | fr | sa | su |
# |4  | tu | we | th | fr | sa | su | mo |
# |5  | we | th | fr | sa | su | mo | tu |
# |6  | th | fr | sa | su | mo | tu | we |
# |7  | fr | sa | su | mo | tu | we | th |
# |8  | sa | su | mo | tu | we | th | fr |
# ----------------------------------------

# %% [markdown]
# # **Structure code for student's average marks**

# %%
# %%writefile avg.c
# #include <stdio.h>
#
# // Define a structure named 'student'
# struct student {
#     char name[50];
#     int roll;
#     int age;
#     float marks[5];
# };
#
# // Main function where the program execution begins
# int main() {
#     struct student s;
#     float sum = 0;
#
#     printf("Enter name: ");
#     scanf("%s", s.name);
#
#     printf("Enter roll no and age: ");
#     scanf("%d%d", &s.roll, &s.age);
#
#     printf("Enter marks of 5 subjects: ");
#     for (int i = 0; i < 5; i++) {
#         scanf("%f", &s.marks[i]);
#         sum += s.marks[i];
#     }
#
#     printf("\nAverage marks: %.2f", sum / 5);
#     return 0;
# }
# Out:
# Writing avg.c

# %%
# !gcc avg.c -lm

# %%
# !./a.out
# Out:
# Enter name: Maanvi
# Enter roll no and age: 101
# 21
# Enter marks of 5 subjects: 18
# 15
# 17
# 16
# 19
#
# Average marks: 17.00

# %% [markdown]
# # **Structure for addition of complex numbers**

# %%
# %%writefile complex.c
# #include<stdio.h>
#
# struct complex{float real,imag;};
#
# int main()
# {
#   struct complex c1,c2,sum;
#
#   printf("Enter first complex number(real imag): ");
#   scanf("%f%f",&c1.real,&c1.imag);
#   printf("Enter second complex number(real imag): ");
#   scanf("%f%f",&c2.real,&c2.imag);
#   sum.real=c1.real+c2.real;
#   sum.imag=c1.imag+c2.imag;
#   printf("Sum=%.2f+%.2fi",sum.real,sum.imag);
#   return 0;
# }
# Out:
# Overwriting complex.c

# %%
# !gcc complex.c -lm

# %%
# !./a.out
# Out:
# Enter first complex number(real imag): 3.5 2.5
# Enter second complex number(real imag): 1.5 4.0
# Sum=5.00+6.50i

# %% [markdown]
# # **Structure code to count 18+ students**

# %%
# %%writefile count.c
# #include <stdio.h>
#
#
# struct student {
#     char name[50];
#     int roll;
#     int age;
# };
#
#
# int main() {
#     struct student s[10];
#     int count = 0;
#
#     // Loop to get input for 10 students
#     for (int i = 0; i < 10; i++) {
#         printf("Enter name, roll, age of student %d: ", i + 1);
#         scanf("%s%d%d", s[i].name, &s[i].roll, &s[i].age);
#         if (s[i].age > 18) count++;
#     }
#
#     printf("\nNumber of students above 18: %d", count);
#     return 0;
# }
# Out:
# Overwriting count.c

# %%
# !gcc count.c -lm

# %%
# !./a.out
# Out:
# Enter name, roll, age of student 1: Maanvi
# 101
# 18
# Enter name, roll, age of student 2: Lakshita
# 102
# 21
# Enter name, roll, age of student 3: Seerat
# 103
# 22
# Enter name, roll, age of student 4: Sonal
# 104
# 25
# Enter name, roll, age of student 5: Rishika
# 105
# 16
# Enter name, roll, age of student 6: Sonali
# 106
# 12
# Enter name, roll, age of student 7: Rahul
# 107
# 23
# Enter name, roll, age of student 8: Manasvi
# 108
# 24
# Enter name, roll, age of student 9: Pinky
# 109
# 25
# Enter name, roll, age of student 10: Komal
# 110
# 23
#
# Number of students above 18: 7

# %% [markdown]
# # **Distance code**

# %%
# %%writefile distance.c
# #include <stdio.h>
#
# // Define a structure named 'distance' to represent a length in feet and inches
# struct distance {
#     int feet;
#     float inch;
# };
#
#
# int main() {
#
#     struct distance d1, d2, sum;
#
#
#     printf("Enter first distance (feet inch): ");
#
#     scanf("%d%f", &d1.feet, &d1.inch);
#
#
#     printf("Enter second distance (feet inch): ");
#
#     scanf("%d%f", &d2.feet, &d2.inch);
#
#
#     sum.feet = d1.feet + d2.feet;
#     sum.inch = d1.inch + d2.inch;
#
#     // Normalize the inches: if inches are 12 or more, convert 12 inches to 1 foot
#     // This loop handles cases where sum.inch might be significantly greater than 12.0
#     while (sum.inch >= 12.0) {
#         sum.inch -= 12.0;
#         sum.feet++;
#     }
#
#
#     printf("Sum of distances = %d' %.2f\"\n", sum.feet, sum.inch);
#     return 0;
# }
# Out:
# Overwriting distance.c

# %%
# !gcc distance.c -lm

# %%
# !./a.out
# Out:
# Enter first distance (feet inch): 5 8.5
# Enter second distance (feet inch): 3 7.5
# Sum of distances = 9' 4.00"

# %% [markdown]
# # **Self refrecial structure code**

# %%
# %%writefile selfref.c
# #include <stdio.h>
#
#
# struct node {
#     int data;
#     struct node *next;
# };
#
#
# int main() {
#
#     struct node n1, n2, n3;
#
#     n1.data = 10;
#     n2.data = 20;
#     n3.data = 30;
#
#     n1.next = &n2;
#     n2.next = &n3;
#     n3.next = NULL;
#
#     struct node *ptr = &n1;
#     printf("Linked list data: ");
#     while (ptr != NULL) {
#         printf("%d ", ptr->data);
#         ptr = ptr->next;
#     }
#     return 0;
# }
# Out:
# Overwriting selfref.c

# %%
# !gcc selfref.c -lm

# %%
# !./a.out
# Out:
# Linked list data: 10 20 30

# %% [markdown]
# # **File Handling...**

# %% [markdown]
# # **Read & Write file**

# %%
# %%writefile fhandle.c
# #include <stdio.h>
#
#
# int main() {
#     FILE *fp;
#     char text[100];
#
#
#     fp = fopen("sample.txt", "w");
#
#     printf("Enter text to write: ");
#
#     fgets(text,sizeof(text),stdin);
#
#     fputs(text, fp);
#
#     fclose(fp);
#
#
#     fp = fopen("sample.txt", "r");
#     printf("\nFile content:\n");
#
#     while (fgets(text, 100, fp)) {
#         printf("%s", text);
#     }
#
#     fclose(fp);
#
#     return 0;
# }
# Out:
# Overwriting fhandle.c

# %%
# !gcc fhandle.c -lm

# %%
# !./a.out
# Out:
# Enter text to write: hello...
#
# File content:
# hello...

# %% [markdown]
# # **Append content**

# %%
# %%writefile app.c
# #include <stdio.h>
# int main() {
#     FILE *fp;
#     char text[100];
#     fp = fopen("sample.txt", "a");
#     printf("Enter text to append: ");
#     fgets(text, sizeof(text), stdin);
#     fputs(text, fp);
#     fclose(fp);
#     printf("Text appended successfully.");
#     return 0;
# }
# Out:
# Overwriting app.c

# %%
# !gcc app.c -lm

# %%
# !./a.out
# Out:
# Enter text to append: Namaste
# Text appended successfully.

# %% [markdown]
# # **Use of fseek(), ftell() & rewind()**

# %%
# %%writefile use.c
# #include <stdio.h>
#
# int main() {
#     FILE *fp;
#     long file_size;
#
#     fp = fopen("sample.txt", "r");
#
#
#     if (fp == NULL) {
#         printf("Error: Could not open file 'sample.txt'\n");
#         return 1;
#     }
#
#
#     fseek(fp, 0, SEEK_END);
#
#
#     file_size = ftell(fp);
#     printf("File size: %ld bytes\n", file_size);
#
#
#     rewind(fp);
#     printf("File pointer reset to beginning. Current position: %ld bytes\n", ftell(fp));
#
#     fclose(fp);
#
#     return 0;
# }
# Out:
# Overwriting use.c

# %%
# !gcc use.c -lm

# %%
# !./a.out
# Out:
# File size: 17 bytes
# File pointer reset to beginning. Current position: 0 bytes

# %% [markdown]
# # **Copy file content**

# %%
# %%writefile copycon.c
# #include <stdio.h>
#
# int main() {
#     FILE *src, *dest;
#     char ch;
#
#     src = fopen("source.txt", "r");
#
#     dest = fopen("copy.txt", "w");
#
#
#     if (src == NULL || dest == NULL) {
#         printf("Error opening file.\n");
#         return 1; // Indicate an error
#     }
#
#
#     while ((ch = fgetc(src)) != EOF) {
#         fputc(ch, dest);
#     }
#
#     printf("File copied successfully.");
#     fclose(src);
#     fclose(dest);
#     return 0;
# }
# Out:
# Overwriting copycon.c

# %%
# !gcc copycon.c -lm

# %%
# !./a.out
# Out:
# Error opening file.
